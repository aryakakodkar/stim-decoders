# %% [markdown]
# # Heralded Erasure Decoder

# %% [markdown]
# This is short demo of how one might use the heralded erasure decoder. As I am still in the process of developing the decoder, its modularity is currently rather limited. In this notebook, I will demonstrate how to create, sample, and decode a rotated surface code circuit in which qubits are exposed to the pure erasure channel with perfect measurements. I hope that in the following months, I will be able to build and demonstrate a more customizable and versatile decoder.

# %% [markdown]
# ## Building Erasure Circuits

# %% [markdown]
# An erasure circuit is one in which some subset of the qubits experience biased (perfectly biased) noise such that the overwhelmingly most likely (certain) error mechanism is a leakage. We assume this leakage is perfectly detectable, informing us of the location of the error (hence, heralded). A leaked qubit state is mathematically equivalent to the initial state having undergone perfectly symmetric $I$, $X$, $Y$, or $Z$, noise (i.e. the perfectly depolarizing channel).

# %% [markdown]
# First, we build our rotated surface code. This is done using the codes module.

# %%
# run the code below to use the right path
import sys
sys.path.append('../..')

# %%
from stimdecoders.utils import codes

# %%
# Build a rotated surface code of distance 3
rsc = codes.RSC(distance=3)

# %% [markdown]
# You can draw the lattice of the surface code, and the CNOT gates for the stabilizer check using the following two functions:

# %%
# draw the surface code lattice
rsc.draw_lattice()

# %%
# draw the surface code checks
rsc.draw_checks()

# %% [markdown]
# To build an erasure circuit, we first need to provide the probabilities of noise in the system. For now, we assume that all qubits can either undergo symmetric Pauli noise, or perfectly biased erasure noise. We will store our noise model in a dictionary (I am still considering the best way to create an object for the noise model).

# %%
noise_dict = {
    'sp': 0.001,
    'sp-e': 0.01,
    'sqg': 0.001,
    'sqg-e': 0.01,
    'tqg': 0.001,
    'tqg-e': 0.01,
}

# %% [markdown]
# Currently, these are the only 6 types of supported noise. They correspond to the following:
# - ```sp```: state preparation
# - ```sqg```: single-qubit gates
# - ```tqg```: two-qubit gates
#
# The ```-e``` flag is the corresponding error probability for erasure qubits. In this example, the state preparation depolarization probability will be $0.001$ for a Pauli qubit (a qubit which experiences Pauli noise) and the state preparation erasure probability will be $0.01$ for an erasure qubit (a qubit which experiences erasure noise).

# %% [markdown]
# Before we build our heralded erasure code, we must define which qubits are Pauli qubits and which qubits are erasure qubits (for now, the two are not independent: all non-Pauli qubits are erasure qubits as these are the only two noise types supported).

# %%
# all qubits are erasure qubits in this example
erasure_qubits = rsc.all_qubit_ids
pauli_qubits = []

# %% [markdown]
# Each qubit in the circuit has a unique 'id.' This is the identifier used in stim when performing gates on the qubit. The id's are displayed in the drawing of the code lattice and the checks. In the above, I have set all qubits to be erasure qubits. In time, I plan to include a more customizable approach to noise allocation. If you want to allocate differently, unfortunately the only way to achieve that currently is to directly append the relevant qubit ids.

# %%
# qubits must be turned to bitmasks
from stimdecoders.utils import bitops
erasure_qubit_mask = bitops.indices_to_mask(erasure_qubits)
pauli_qubit_mask = bitops.indices_to_mask(pauli_qubits) # we could equivalently initialize this as 0b0

# %% [markdown]
# For efficiency, operations are performed using bitmasks. The erasure and Pauli bitmasks are integer bitstrings which contain '1's at the indices corresponding to erasure and Pauli qubits, respectively, and '0's everywhere else. We store these bitmasks in the noise_dict dictionary.

# %%
noise_dict['erasure-qubits'] = erasure_qubit_mask
noise_dict['pauli-qubits'] = pauli_qubit_mask

# %% [markdown]
# Now the initialization process is complete, we can actually build the erasure circuit.

# %%
from stimdecoders.hed import hed
# build the heralded erasure code
erasure_circuit = hed.build_heralded_erasure_circuit(code=rsc, noise_dict=noise_dict)

# %% [markdown]
# This circuit is an instance of ```stimdecoders.circuits.Circuit```. This is useful for a number of reasons, but if you simply want the stim circuit to see what's going on underneath the hood, there are two ways to achieve that:
# - you can convert the ```stimdecoders.circuits.Circuit``` to a ```stim.Circuit``` object using the function ```to_stim_circuit()```
# - you can initialize erasure_circuit as a stim circuit from the get-go (use ```build_heralded_erasure_stim_circuit``` instead of ```build_heralded_erasure_circuit```)

# %%
erasure_stim_circuit = erasure_circuit.to_stim_circuit()

# %% [markdown]
# You can probe this stim circuit as you would any other stim circuit. A word of warning: I have yet to introduce annotations into the stim circuits, so any diagrams outside of ```timeline-svg``` will not make much sense.

# %%
erasure_stim_circuit.diagram('timeline-svg')
# Out:
# <svg viewBox="0 0 39968 3360"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L39936,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L39936,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L39936,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L39936,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# <path id="qubit_line:4" d="M64,320 L39936,320 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="320">q4</text>
# <path id="qubit_line:5" d="M64,384 L39936,384 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="384">q5</text>
# <path id="qubit_line:6" d="M64,448 L39936,448 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="448">q6</text>
# <path id="qubit_line:7" d="M64,512 L39936,512 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="512">q7</text>
# <path id="qubit_line:8" d="M64,576 L39936,576 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="576">q8</text>
# <path id="qubit_line:9" d="M64,640 L39936,640 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="640">q9</text>
# <path id="qubit_line:10" d="M64,704 L39936,704 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="704">q10</text>
# <path id="qubit_line:11" d="M64,768 L39936,768 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="768">q11</text>
# <path id="qubit_line:12" d="M64,832 L39936,832 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="832">q12</text>
# <path id="qubit_line:13" d="M64,896 L39936,896 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="896">q13</text>
# <path id="qubit_line:14" d="M64,960 L39936,960 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="960">q14</text>
# <path id="qubit_line:15" d="M64,1024 L39936,1024 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1024">q15</text>
# <path id="qubit_line:16" d="M64,1088 L39936,1088 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1088">q16</text>
# <path id="qubit_line:17" d="M64,1152 L39936,1152 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1152">q17</text>
# <path id="qubit_line:18" d="M64,1216 L39936,1216 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1216">q18</text>
# <path id="qubit_line:19" d="M64,1280 L39936,1280 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1280">q19</text>
# <path id="qubit_line:20" d="M64,1344 L39936,1344 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1344">q20</text>
# <path id="qubit_line:21" d="M64,1408 L39936,1408 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1408">q21</text>
# <path id="qubit_line:22" d="M64,1472 L39936,1472 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1472">q22</text>
# <path id="qubit_line:23" d="M64,1536 L39936,1536 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1536">q23</text>
# <path id="qubit_line:24" d="M64,1600 L39936,1600 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1600">q24</text>
# <path id="qubit_line:25" d="M64,1664 L39936,1664 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1664">q25</text>
# <path id="qubit_line:26" d="M64,1728 L39936,1728 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1728">q26</text>
# <path id="qubit_line:27" d="M64,1792 L39936,1792 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1792">q27</text>
# <path id="qubit_line:28" d="M64,1856 L39936,1856 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1856">q28</text>
# <path id="qubit_line:29" d="M64,1920 L39936,1920 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1920">q29</text>
# <path id="qubit_line:30" d="M64,1984 L39936,1984 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="1984">q30</text>
# <path id="qubit_line:31" d="M64,2048 L39936,2048 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2048">q31</text>
# <path id="qubit_line:32" d="M64,2112 L39936,2112 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2112">q32</text>
# <path id="qubit_line:33" d="M64,2176 L39936,2176 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2176">q33</text>
# <path id="qubit_line:34" d="M64,2240 L39936,2240 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2240">q34</text>
# <path id="qubit_line:35" d="M64,2304 L39936,2304 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2304">q35</text>
# <path id="qubit_line:36" d="M64,2368 L39936,2368 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2368">q36</text>
# <path id="qubit_line:37" d="M64,2432 L39936,2432 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2432">q37</text>
# <path id="qubit_line:38" d="M64,2496 L39936,2496 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2496">q38</text>
# <path id="qubit_line:39" d="M64,2560 L39936,2560 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2560">q39</text>
# <path id="qubit_line:40" d="M64,2624 L39936,2624 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2624">q40</text>
# <path id="qubit_line:41" d="M64,2688 L39936,2688 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2688">q41</text>
# <path id="qubit_line:42" d="M64,2752 L39936,2752 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2752">q42</text>
# <path id="qubit_line:43" d="M64,2816 L39936,2816 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2816">q43</text>
# <path id="qubit_line:44" d="M64,2880 L39936,2880 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2880">q44</text>
# <path id="qubit_line:45" d="M64,2944 L39936,2944 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="2944">q45</text>
# <path id="qubit_line:46" d="M64,3008 L39936,3008 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="3008">q46</text>
# <path id="qubit_line:47" d="M64,3072 L39936,3072 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="3072">q47</text>
# <path id="qubit_line:48" d="M64,3136 L39936,3136 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="3136">q48</text>
# <path id="qubit_line:49" d="M64,3200 L39936,3200 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="3200">q49</text>
# <path id="qubit_line:50" d="M64,3264 L39936,3264 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="3264">q50</text>
# </g>
# <rect x="80" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="128" fill="white">R</text>
# <rect x="80" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="192" fill="white">R</text>
# <rect x="80" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="256" fill="white">R</text>
# <rect x="80" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="384" fill="white">R</text>
# <rect x="80" y="560" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="576" fill="white">R</text>
# <rect x="80" y="624" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="640" fill="white">R</text>
# <rect x="80" y="688" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="704" fill="white">R</text>
# <rect x="80" y="752" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="768" fill="white">R</text>
# <rect x="80" y="816" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="832" fill="white">R</text>
# <rect x="80" y="880" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="896" fill="white">R</text>
# <rect x="80" y="944" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="960" fill="white">R</text>
# <rect x="80" y="1008" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="1024" fill="white">R</text>
# <rect x="80" y="1072" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="1088" fill="white">R</text>
# <rect x="80" y="1136" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="1152" fill="white">R</text>
# <rect x="80" y="1200" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="1216" fill="white">R</text>
# <rect x="80" y="1264" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="1280" fill="white">R</text>
# <rect x="80" y="1648" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="1664" fill="white">R</text>
# <rect x="144" y="112" width="32" height="32" stroke="black" fill="#800000"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="8" x="160" y="128" fill="white">HErase</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="160" y="148">0.01</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="160" y="108">rec[0]</text>
# <rect x="144" y="240" width="32" height="32" stroke="black" fill="#800000"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="8" x="160" y="256" fill="white">HErase</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="160" y="276">0.01</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="160" y="236">rec[1]</text>
# <rect x="144" y="368" width="32" height="32" stroke="black" fill="#800000"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="8" x="160" y="384" fill="white">HErase</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="160" y="404">0.01</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="160" y="364">rec[2]</text>
# <rect x="144" y="560" width="32" height="32" stroke="black" fill="#800000"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="8" x="160" y="576" fill="white">HErase</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="160" y="596">0.01</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="160" y="556">rec[3]</text>
# <rect x="144" y="688" width="32" height="32" stroke="black" fill="#800000"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="8" x="160" y="704" fill="white">HErase</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="160" y="724">0.01</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="160" y="684">rec[4]</text>
# <rect x="144" y="816" width="32" height="32" stroke="black" fill="#800000"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="8" x="160" y="832" fill="white">HErase</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="160" y="852">0.01</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="160" y="812">rec[5]</text>
# <rect x="144" y="1008" width="32" height="32" stroke="black" fill="#800000"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="8" x="160" y="1024" fill="white">HErase</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="160" y="1044">0.01</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="160" y="1004">rec[6]</text>
# <rect x="144" y="1136" width="32" height="32" stroke="black" fill="#800000"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="8" x="160" y="1152" fill="white">HErase</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="160" y="1172">0.01</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="160" y="1132">rec[7]</text>
# <rect x="144" y="1264" width="32" height="32" stroke="black" fill="#800000"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="8" x="160" y="1280" fill="white">HErase</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="160" y="1300">0.01</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="160" y="1260">rec[8]</text>
# <rect x="144" y="176" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="160" y="192">H</text>
# <rect x="144" y="752" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="160" y="768">H</text>
# <rect x="144" y="1072" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="160" y="1088">H</text>
# <rect x="144" y="1648" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="160" y="1664">H</text>
# <rect x="208" y="176" width="32" height="32" stroke="black" fill="#800000"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="8" x="224" y="192" fill="white">HErase</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="224" y="212">0.01</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="224" y="172">rec[9]</text>
# <rect x="208" y="752" width="32" height="32" stroke="black" fill="#800000"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="8" x="224" y="768" fill="white">HErase</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="224" y="788">0.01</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="224" y="748">rec[10]</text>
# <rect x="208" y="1072" width="32" height="32" stroke="black" fill="#800000"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="8" x="224" y="1088" fill="white">HErase</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="224" y="1108">0.01</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="224" y="1068">rec[11]</text>
# <rect x="208" y="1648" width="32" height="32" stroke="black" fill="#800000"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="8" x="224" y="1664" fill="white">HErase</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="224" y="1684">0.01</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="224" y="1644">rec[12]</text>
# <path d="M288,128 L288,192 " stroke="black"/>
# <circle cx="288" cy="192" r="12" stroke="none" fill="black"/>
# <circle cx="288" cy="128" r="12" stroke="black" fill="white"/>
# <path d="M276,128 L300,128 M288,116 L288,140 " stroke="black"/>
# <path d="M288,704 L288,768 " stroke="black"/>
# <circle cx="288" cy="768" r="12" stroke="none" fill="black"/>
# <circle cx="288" cy="704" r="12" stroke="black" fill="white"/>
# <path d="M276,704 L300,704 M288,692 L288,716 " stroke="black"/>
# <path d="M288,1024 L288,1088 " stroke="black"/>
# <circle cx="288" cy="1088" r="12" stroke="none" fill="black"/>
# <circle cx="288" cy="1024" r="12" stroke="black" fill="white"/>
# <path d="M276,1024 L300,1024 M288,1012 L288,1036 " stroke="black"/>
# <path d="M288,576 L288,640 " stroke="black"/>
# <circle cx="288" cy="576" r="12" stroke="none" fill="black"/>
# <circle cx="288" cy="640" r="12" stroke="black" fill="white"/>
# <path d="M276,640 L300,640 M288,628 L288,652 " stroke="black"/>
# <path d="M288,832 L288,896 " stroke="black"/>
# <circle cx="288" cy="832" r="12" stroke="none" fill="black"/>
# <circle cx="288" cy="896" r="12" stroke="black" fill="white"/>
# <path d="M276,896 L300,896 M288,884 L288,908 " stroke="black"/>
# <path d="M288,1152 L288,1216 " stroke="black"/>
# <circle cx="288" cy="1152" r="12" stroke="none" fill="black"/>
# <circle cx="288" cy="1216" r="12" stroke="black" fill="white"/>
# <path d="M276,1216 L300,1216 M288,1204 L288,1228 " stroke="black"/>
# <path d="M352,128 L352,1728 " stroke="black"/>
# <rect x="336" y="112" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="352" y="128">E<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="336" y="1712" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="352" y="1728">E<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="352" y="1748">0.000416667</text>
# <path d="M416,128 L416,1728 " stroke="black"/>
# <rect x="400" y="112" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="416" y="128">EE<tspan baseline-shift="sub" font-size="10">Y</tspan></text>
# <rect x="400" y="1712" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="416" y="1728">EE<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="416" y="1748">0.00041684</text>
# <path d="M480,128 L480,1728 " stroke="black"/>
# <rect x="464" y="112" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="480" y
width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="38816" y="2816">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="38816" y="2796">D58 = rec[58]</text>
# <rect x="38736" y="2864" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="38816" y="2880">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="38816" y="2860">D59 = rec[59]</text>
# <rect x="38736" y="3248" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="38816" y="3264">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="38816" y="3244">D60 = rec[60]</text>
# <rect x="38736" y="176" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="38816" y="192">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="38816" y="172">D61 = rec[61]</text>
# <rect x="38736" y="752" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="38816" y="768">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="38816" y="748">D62 = rec[62]</text>
# <rect x="38736" y="1072" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="38816" y="1088">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="38816" y="1068">D63 = rec[63]</text>
# <rect x="38736" y="1648" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="38816" y="1664">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="38816" y="1644">D64 = rec[64]</text>
# <rect x="38928" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="38944" y="192" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="38944" y="172">rec[65]</text>
# <rect x="38928" y="752" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="38944" y="768" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="38944" y="748">rec[66]</text>
# <rect x="38928" y="1072" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="38944" y="1088" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="38944" y="1068">rec[67]</text>
# <rect x="38928" y="1648" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="38944" y="1664" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="38944" y="1644">rec[68]</text>
# <rect x="38928" y="624" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="38944" y="640" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="38944" y="620">rec[69]</text>
# <rect x="38928" y="880" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="38944" y="896" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="38944" y="876">rec[70]</text>
# <rect x="38928" y="944" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="38944" y="960" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="38944" y="940">rec[71]</text>
# <rect x="38928" y="1200" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="38944" y="1216" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="38944" y="1196">rec[72]</text>
# <rect x="38992" y="624" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="39072" y="640">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="39072" y="620">D65 = rec[69]</text>
# <rect x="38992" y="880" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="39072" y="896">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="39072" y="876">D66 = rec[70]</text>
# <rect x="38992" y="944" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="39072" y="960">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="39072" y="940">D67 = rec[71]</text>
# <rect x="38992" y="1200" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="39072" y="1216">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="39072" y="1196">D68 = rec[72]</text>
# <rect x="38992" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="39008" y="128" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="39008" y="108">rec[73]</text>
# <rect x="38992" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="39008" y="256" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="39008" y="236">rec[74]</text>
# <rect x="38992" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="39008" y="384" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="39008" y="364">rec[75]</text>
# <rect x="38992" y="560" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="39008" y="576" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="39008" y="556">rec[76]</text>
# <rect x="38992" y="688" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="39008" y="704" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="39008" y="684">rec[77]</text>
# <rect x="38992" y="816" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="39008" y="832" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="39008" y="812">rec[78]</text>
# <rect x="38992" y="1008" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="39008" y="1024" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="39008" y="1004">rec[79]</text>
# <rect x="38992" y="1136" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="39008" y="1152" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="39008" y="1132">rec[80]</text>
# <rect x="38992" y="1264" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="39008" y="1280" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="39008" y="1260">rec[81]</text>
# <rect x="39184" y="112" width="416" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="39392" y="128">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="39392" y="108">D69 = rec[76]*rec[73]*rec[77]*rec[74]*rec[69]</text>
# <rect x="39184" y="368" width="288" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="39328" y="384">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="39328" y="364">D70 = rec[78]*rec[75]*rec[70]</text>
# <rect x="39184" y="560" width="288" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="39328" y="576">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="39328" y="556">D71 = rec[79]*rec[76]*rec[71]</text>
# <rect x="39184" y="688" width="416" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="39392" y="704">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="39392" y="684">D72 = rec[80]*rec[77]*rec[81]*rec[78]*rec[72]</text>
# <rect x="39632" y="112" width="288" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="39776" y="128">OBS_INCLUDE(0)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="39776" y="108">L0 *= rec[73]*rec[74]*rec[75]</text>
# </svg>

# %% [markdown]
# This circuit looks quite complex for a simple distance 3 rotated surface code with a single round of syndrome extraction. The reason for this is that stim does not have any in-built features allowing for 2-qubit non-Pauli noise (e.g. erasure-erasure or Pauli-Pauli). Therefore, our solution is to create a number of fictitious qubits (```q26``` to ```q50```, in this case), the Z-basis state of which is directly correlated to the state of a real qubit (under noiseless conditions). We use measurements of these ancilla in the Z-basis to act as our heralds.

# %% [markdown]
# ## Sampling Erasure Circuits

# %% [markdown]
# We can sample an erasure circuit just as we do any stim circuit. The method ```stimdetectors.hed.sample_erasure_circuit``` is built for just this purpose.

# %%
syndromes, observable_flips = hed.sample_erasure_circuit(erasure_stim_circuit, num_shots=10) # you can also pass in a stimdetectors.circuits.Circuit object

# %% [markdown]
# ## Decoding Erasure Circuits

# %% [markdown]
# The tough part is decoding. A traditional minimum-weight perfect matching (MWPM) will not do particularly well on this circuit directly, because of the existence of fictitious ancillas (among other things). Hence, we must manually extract the syndromes and build traditional Clifford circuits (circuits with no erasures). At any time along the circuit, if a qubit has undergone an erasure, it may be modelled having been passed through a perfectly depolarizing error channel (one-quarter probability of each possible Pauli error). Any qubit which does not undergo an erasure can be treated as noiseless.

# %%
clifford_circuit = hed.build_clifford_circuit(rsc, erasure_circuit, syndromes[0], noise_dict=noise_dict)

# %% [markdown]
# The above code builds the Clifford circuit corresponding to the first erasure syndrome we sampled. If you are unclear on what is going on, I highly recommend going through the various lines of each circuit, and seeing how they match up. You will find that the qubits which undergo depolarizing errors in the Clifford circuit are exactly those which are measured as having been erased (you can see this via the syndrome).

# %% [markdown]
# We can now use PyMatching to decode our Clifford circuit, but with the syndrome from our erasure circuit (the two circuits are equivalent, _a posteriori_). We will only consider the last 8 detector measurements from the syndrome, as these correspond to the detectors in the Clifford circuit (in this case, it is 8. More generally, the number of detectors is equal to the number of ancillas in the rotated surface code).

# %%
import pymatching
matching = pymatching.Matching.from_stim_circuit(clifford_circuit.to_stim_circuit())
decoded_flip = matching.decode(z=syndromes[0][-8:]) # only pass in the last 8 detectors

# %% [markdown]
# Stim stores the state of the observable (Flipped: ```True```, Unflipped: ```False```), and ```PyMatching.decode``` does the same, but as 0s and 1s. You will almost certainly find (unless you are very unlucky) that the ```observable_flips[0]``` and ```decoded_flips``` objects match.

# %%
observable_flips[0]
# Out:
# array([False])

# %%
decoded_flip
# Out:
# array([0], dtype=uint8)

# %% [markdown]
# This method of decoding can be rather slow, unfortunately. For this reason, I've built a (somewhat) time-efficient batch circuit-builder. You simply batch-sample a very large number of shots of the stim erasure circuit, and feed into the ```stimdecoders.hed.batch.BatchCircuitBuilder.build_batch()``` method, which will build a batch of Clifford circuits corresponding to syndromes.

# %%
from stimdecoders.hed import batch
batch_builder = batch.BatchCircuitBuilder(rsc=rsc, erasure_circuit=erasure_circuit, noise_dict=noise_dict) # only supports rotated surface codes
clifford_batch = batch_builder.build_batch(syndromes)
# an even faster method would be to use the build_batch_with_cache method (but this is more memory intensive)

# %% [markdown]
# You can then perform the decoding step on each of these Clifford circuits. If you'd rather skip ahead, you may choose to use the ```stimdecoders.hed.hed.batch_decode_pure_erasure_circuit()``` method. Pass in your erasure circuit, and the number of shots you'd like to run, and this function will automatically build your Clifford circuits _and_ decode them for you.

# %%
hed.batch_decode_pure_erasure_circuit(rsc=rsc, erasure_circuit=erasure_circuit, num_trials=10000, noise_dict=noise_dict)
# Out:
# 2

# %% [markdown]
# The output of the above cell is the number of errors which occurred in ```num_trials``` trials. If you prefer the batch decoder to return the actual observable flip predictions for each, simply set the ```return_data``` argument (default: ```False```) to ```True```.
